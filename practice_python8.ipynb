# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/alankritmahajan/Downloads/netflix_titles 2.csv')

# %%
data.head(1)
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
 # is there any duplicate record in data set

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates().head(1)
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %%
# showing null value with heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
# For house of cards, what is the show id and who is the director of the show?

# %%
data.head(1)
data[data['title'] == 'House of Cards'][['show_id', 'director', 'title']]
# Out:
#      show_id director           title
# 2832   s2833      NaN  House of Cards

# %%
# In which year highest no. of movies and tv shows were released? Show with bar graph

# %%
data.head(1)
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %%
data.groupby('release_year').show_id.count().sort_values(ascending = False).head(1)
# Out:
# release_year
# 2018    1121
# Name: show_id, dtype: int64

# %%
data.groupby('release_year').show_id.count().sort_values(ascending = False).head(5).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
# How many movies and Tv shows are in the data set? Show with the bardata graph.

# %%
data['type'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
data['type'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data['type'])
# Out:
# /Users/alankritmahajan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
# Show all the movies that were released in year 2000?

# %%
data.head(2)
data[(data['type'] == "Movie") & (data['release_year'] == 2000)]
# Out:
#      show_id   type                                              title  \
# 94       s95  Movie                                            28 Days
# 473     s474  Movie                                    American Psycho
# 488     s489  Movie  An American Tail: The Treasures of Manhattan I...
# 927     s928  Movie                                       Billy Elliot
# 1256   s1257  Movie                                       Center Stage
# 1262   s1263  Movie                                     Chal Mere Bhai
# 1280   s1281  Movie                                   Charlie's Angels
# 1546   s1547  Movie                     Crouching Tiger, Hidden Dragon
# 1851   s1852  Movie                       Dragonheart: A New Beginning
# 2163   s2164  Movie                                  Final Destination
# 2200   s2201  Movie                                               Fiza
# 2588   s2589  Movie                          Hamara Dil Aapke Paas Hai
# ...

# %%
# show only the titles of the tv show that were released in india only.

# %%
data[(data['country'] == 'India') & (data['title'] == 'TV Show')].title
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# show the top directors. who gave highest no. of tv shows and movies to netflix

# %%
data.groupby('director').title.count().sort_values(ascending = False)
# Out:
# director
# Raúl Campos, Jan Suter             18
# Marcus Raboy                       16
# Jay Karas                          14
# Cathy Garcia-Molina                13
# Martin Scorsese                    12
#                                    ..
# Jon Hurwitz, Hayden Schlossberg     1
# Jon Izen                            1
# Jon J. Whelan                       1
# Benjamin Cohen, Nicolas Cotto       1
# Kevin Reynolds                      1
# Name: title, Length: 4049, dtype: int64

# %%
# show the record where the movie is comedy or country is uk

# %%
data[((data['listed_in'].str.contains("Comedies"))
      & (data['type'] == 'Movie')) | (data['country'].str.contains('United Kingdom'))]
# Out:
#      show_id   type                                    title  \
# 18       s19  Movie                                   15-Aug
# 19       s20  Movie                                      '89
# 33       s34  Movie                             #realityhigh
# 34       s35  Movie                                    #Roxy
# 36       s37  Movie                                  #Selfie
# ...      ...    ...                                      ...
# 7772   s7773  Movie        Zipi & Zape y la Isla del Capitan
# 7778   s7779  Movie                               Zombieland
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                 director                                               cast  \
# 18    Swapnaneel Jayakar  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# 19                   NaN                 Lee Dixon, Ian Wright, Paul Merson
# ...

# %%
# In how many movies/shows was he cast.

# %%
data1 = data[data['cast'].str.contains('Tom Cruise', na=False)] 
data1
# na = false The na=False parameter ensures that NaN values are treated as False in the boolean mask.
# or use data = data.dropna()
# Out:
#      show_id   type     title              director  \
# 3860   s3861  Movie  Magnolia  Paul Thomas Anderson
# 5070   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5070  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#            date_added  release_year rating duration  \
# 3860  January 1, 2020          1999      R  189 min
# 5070     July 1, 2019          1988      R  134 min
#
#                        listed_in  \
# 3860  Dramas, Independent Movies
# 5070      Classic Movies, Dramas
#
#                                             description
# 3860  Through chance, human action, past history and...
# 5070  A fast-talking yuppie is forced to slow down w...

# %%
# what are the different rating defined by netflix?
data = data.dropna()

# %%
data['rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# How many movies got tv-14 rating in canada?

# %%
data[(data["type"] == 'Movie') & (data["country"].str.contains('Canada')) & 
     (data["rating"] == 'TV-14')].head(2)
# Out:
#     show_id   type           title         director  \
# 34      s35  Movie           #Roxy  Michael Kennedy
# 608    s609  Movie  At First Light      Jason Stone
#
#                                                   cast country  \
# 34   Jake Short, Sarah Fisher, Booboo Stewart, Dann...  Canada
# 608  Stefanie Scott, Theodore Pellerin, Percy Hynes...  Canada
#
#             date_added  release_year rating duration  \
# 34      April 10, 2019          2018  TV-14  105 min
# 608  December 27, 2018          2018  TV-14   91 min
#
#                      listed_in  \
# 34   Comedies, Romantic Movies
# 608   Dramas, Sci-Fi & Fantasy
#
#                                            description
# 34   A teenage hacker with a huge nose helps a cool...
# 608  After mysterious lights imbue her with extraor...

# %%
# How many tv shows got R rating after year 2018

# %%
data[(data["release_year"] > 2018) & (data["type"] == 'TV Show') & (data["rating"] == 'R')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# what is the max duration for movie/show

# %%
data.loc[:, ['Minutes', 'Units']] = data['duration'].str.split(' ', expand = True)
# Out:
# /var/folders/dx/5fxhhtq94_l7kbnby0lq0rbr0000gn/T/ipykernel_73191/3724851931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, ['Minutes', 'Units']] = data['duration'].str.split(' ', expand = True)

# %%
data = data.copy()
data[['Minutes', 'Units']] = data['duration'].str.split(' ', expand=True)

# %%
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[data['Units'] == 'Seasons'].sort_values(by = 'Minutes', ascending = False)
# Out:
#      show_id     type                                    title  \
# 1181   s1182  TV Show                         Call the Midwife
# 4404   s4405  TV Show                                   Naruto
# 6415   s6416  TV Show            The Great British Baking Show
# 5291   s5292  TV Show                              Royal Pains
# 584     s585  TV Show                                    Arrow
# 6359   s6360  TV Show                                The Flash
# 1470   s1471  TV Show         Comedians in Cars Getting Coffee
# 2130   s2131  TV Show                             Father Brown
# 4033   s4034  TV Show                         Men on a Mission
# 5908   s5909  TV Show                                Supergirl
# 4047   s4048  TV Show                                   Merlin
# 4121   s4122  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 2504   s2505  TV Show                                   Gotham
# 2313   s2314  TV Show         Fullmetal Alchemist: Brotherhood
# ...

# %%
#Which country has the hioghts no. of tv shows?
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data_tvshow = data[data['type'] == "TV Show"]

# %%
data_tvshow.country.value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: country, Length: 183, dtype: int64

# %%
# Q3 find instance where movie is drama or tvshow is kids tv

# %%
data[ ((data['type'] == 'Movie') & (data['listed_in'].str.contains('Dramas', na = False))) |
     (data['type'] == 'TV Show') & ((data['listed_in'].str.contains('Kids', na = False)))]
# Out:
#      show_id     type        title           director  \
# 1         s2    Movie         7:19  Jorge Michel Grau
# 4         s5    Movie           21     Robert Luketic
# 7         s8    Movie          187     Kevin Reynolds
# 10       s11    Movie         1922       Zak Hilditch
# 15       s16    Movie       Oct-01     Kunle Afolayan
# ...      ...      ...          ...                ...
# 7776   s7777    Movie     Zokkomon   Satyajit Bhatkal
# 7777   s7778  TV Show  Zombie Dumb                NaN
# 7780   s7781    Movie          Zoo       Shlok Sharma
# 7782   s7783    Movie         Zozo        Josef Fares
# 7783   s7784    Movie       Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...
